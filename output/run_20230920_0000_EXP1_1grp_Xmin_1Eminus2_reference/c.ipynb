# %% [markdown]
# # Carbon

# %% [markdown]
# Use conda environment python3

# %% [markdown]
# ## Load libraries

# %%
import netcdf_tools
import numpy as np

# %% [markdown]
# ## Select year

# %%
nbyr=10
years=range(1,nbyr+1)
array1d_iT_iTforplot=np.arange(1,365*nbyr+1)
array1d_iT_iTforpcolormesh=np.arange(1,365*nbyr+2)
locs=list()
xticklabels=range(5,nbyr+1,5)
for year in xticklabels:
    loc=1+365*(year-1)
    locs.append(loc)

# %% [markdown]
# ## Read outputs

# %% [markdown]
# RF is the r coordinate of cell intrface (in m)

# %%
gridfile='grid.t001.nc';
RF=netcdf_tools.read_netcdf(gridfile,'RF')

# %% [markdown]
# drF is the r cell face separation, meaning the thickness of each depth layer (in m)
#
# it corresponds to delR on https://mitgcm.readthedocs.io/en/latest/getting_started/getting_started.html#grid

# %%
drF=netcdf_tools.read_netcdf(gridfile,'drF')

# %%
# 80 characters
#xxxxxxxxx xxxxxxxxx xxxxxxxxx xxxxxxxxx xxxxxxxxx xxxxxxxxx xxxxxxxxx xxxxxxxxl

# %%
gudfile='car.0000000000.t001.nc';

# DIC; mmol C m^-3
array2d_idepth_iT_DIC\
=netcdf_tools.read_netcdf(gudfile, 'TRAC01').squeeze().transpose()
array2d_idepth_iT_DIC[-1,:]=np.nan

# PIC; mmol C m^-3
array2d_idepth_iT_PIC\
=netcdf_tools.read_netcdf(gudfile, 'TRAC17').squeeze().transpose()
array2d_idepth_iT_PIC[-1,:]=np.nan

# DOC; mmol C m^-3
array2d_idepth_iT_DOC\
=netcdf_tools.read_netcdf(gudfile, 'TRAC08').squeeze().transpose()
array2d_idepth_iT_DOC[-1,:]=np.nan

# POC; mmol C m^-3
array2d_idepth_iT_POC\
=netcdf_tools.read_netcdf(gudfile, 'TRAC12').squeeze().transpose()
array2d_idepth_iT_POC[-1,:]=np.nan

array2d_idepth_iT_pro\
=netcdf_tools.read_netcdf(gudfile, 'TRAC21').squeeze().transpose()
array2d_idepth_iT_pro[-1,:]=np.nan

array2d_idepth_iT_syn\
=netcdf_tools.read_netcdf(gudfile, 'TRAC22').squeeze().transpose()
array2d_idepth_iT_syn[-1,:]=np.nan

array2d_idepth_iT_smalleuk01\
=netcdf_tools.read_netcdf(gudfile, 'TRAC23').squeeze().transpose()
array2d_idepth_iT_smalleuk01[-1,:]=np.nan
array2d_idepth_iT_smalleuk02\
=netcdf_tools.read_netcdf(gudfile, 'TRAC24').squeeze().transpose()
array2d_idepth_iT_smalleuk02[-1,:]=np.nan

array2d_idepth_iT_smalleuk\
=array2d_idepth_iT_smalleuk01+array2d_idepth_iT_smalleuk02

array2d_idepth_iT_cocco01\
=netcdf_tools.read_netcdf(gudfile, 'TRAC25').squeeze().transpose()
array2d_idepth_iT_cocco01[-1,:]=np.nan
array2d_idepth_iT_cocco02\
=netcdf_tools.read_netcdf(gudfile, 'TRAC26').squeeze().transpose()
array2d_idepth_iT_cocco02[-1,:]=np.nan
array2d_idepth_iT_cocco03\
=netcdf_tools.read_netcdf(gudfile, 'TRAC27').squeeze().transpose()
array2d_idepth_iT_cocco03[-1,:]=np.nan
array2d_idepth_iT_cocco04\
=netcdf_tools.read_netcdf(gudfile, 'TRAC28').squeeze().transpose()
array2d_idepth_iT_cocco04[-1,:]=np.nan
array2d_idepth_iT_cocco05\
=netcdf_tools.read_netcdf(gudfile, 'TRAC29').squeeze().transpose()
array2d_idepth_iT_cocco05[-1,:]=np.nan

array2d_idepth_iT_cocco\
=array2d_idepth_iT_cocco01+array2d_idepth_iT_cocco02\
+array2d_idepth_iT_cocco03+array2d_idepth_iT_cocco04\
+array2d_idepth_iT_cocco05

array2d_idepth_iT_diazo01\
=netcdf_tools.read_netcdf(gudfile, 'TRAC30').squeeze().transpose()
array2d_idepth_iT_diazo01[-1,:]=np.nan
array2d_idepth_iT_diazo02\
=netcdf_tools.read_netcdf(gudfile, 'TRAC31').squeeze().transpose()
array2d_idepth_iT_diazo02[-1,:]=np.nan
array2d_idepth_iT_diazo03\
=netcdf_tools.read_netcdf(gudfile, 'TRAC32').squeeze().transpose()
array2d_idepth_iT_diazo03[-1,:]=np.nan
array2d_idepth_iT_diazo04\
=netcdf_tools.read_netcdf(gudfile, 'TRAC33').squeeze().transpose()
array2d_idepth_iT_diazo04[-1,:]=np.nan

array2d_idepth_iT_diazo\
=array2d_idepth_iT_diazo01+array2d_idepth_iT_diazo02\
+array2d_idepth_iT_diazo03+array2d_idepth_iT_diazo04

array2d_idepth_iT_tri\
=netcdf_tools.read_netcdf(gudfile, 'TRAC34').squeeze().transpose()
array2d_idepth_iT_tri[-1,:]=np.nan

array2d_idepth_iT_diatom03\
=netcdf_tools.read_netcdf(gudfile, 'TRAC35').squeeze().transpose()
array2d_idepth_iT_diatom03[-1,:]=np.nan
array2d_idepth_iT_diatom04\
=netcdf_tools.read_netcdf(gudfile, 'TRAC36').squeeze().transpose()
array2d_idepth_iT_diatom04[-1,:]=np.nan
array2d_idepth_iT_diatom05\
=netcdf_tools.read_netcdf(gudfile, 'TRAC37').squeeze().transpose()
array2d_idepth_iT_diatom05[-1,:]=np.nan
array2d_idepth_iT_diatom06\
=netcdf_tools.read_netcdf(gudfile, 'TRAC38').squeeze().transpose()
array2d_idepth_iT_diatom06[-1,:]=np.nan
array2d_idepth_iT_diatom07\
=netcdf_tools.read_netcdf(gudfile, 'TRAC39').squeeze().transpose()
array2d_idepth_iT_diatom07[-1,:]=np.nan
array2d_idepth_iT_diatom08\
=netcdf_tools.read_netcdf(gudfile, 'TRAC40').squeeze().transpose()
array2d_idepth_iT_diatom08[-1,:]=np.nan
array2d_idepth_iT_diatom09\
=netcdf_tools.read_netcdf(gudfile, 'TRAC41').squeeze().transpose()
array2d_idepth_iT_diatom09[-1,:]=np.nan
array2d_idepth_iT_diatom10\
=netcdf_tools.read_netcdf(gudfile, 'TRAC42').squeeze().transpose()
array2d_idepth_iT_diatom10[-1,:]=np.nan
array2d_idepth_iT_diatom11\
=netcdf_tools.read_netcdf(gudfile, 'TRAC43').squeeze().transpose()
array2d_idepth_iT_diatom11[-1,:]=np.nan

array2d_idepth_iT_diatom\
=array2d_idepth_iT_diatom03+array2d_idepth_iT_diatom04\
+array2d_idepth_iT_diatom05+array2d_idepth_iT_diatom06\
+array2d_idepth_iT_diatom07+array2d_idepth_iT_diatom08\
+array2d_idepth_iT_diatom09+array2d_idepth_iT_diatom10\
+array2d_idepth_iT_diatom11

array2d_idepth_iT_largeeuk01\
=netcdf_tools.read_netcdf(gudfile, 'TRAC44').squeeze().transpose()
array2d_idepth_iT_largeeuk01[-1,:]=np.nan
array2d_idepth_iT_largeeuk02\
=netcdf_tools.read_netcdf(gudfile, 'TRAC45').squeeze().transpose()
array2d_idepth_iT_largeeuk02[-1,:]=np.nan
array2d_idepth_iT_largeeuk03\
=netcdf_tools.read_netcdf(gudfile, 'TRAC46').squeeze().transpose()
array2d_idepth_iT_largeeuk03[-1,:]=np.nan
array2d_idepth_iT_largeeuk04\
=netcdf_tools.read_netcdf(gudfile, 'TRAC47').squeeze().transpose()
array2d_idepth_iT_largeeuk04[-1,:]=np.nan
array2d_idepth_iT_largeeuk05\
=netcdf_tools.read_netcdf(gudfile, 'TRAC48').squeeze().transpose()
array2d_idepth_iT_largeeuk05[-1,:]=np.nan
array2d_idepth_iT_largeeuk06\
=netcdf_tools.read_netcdf(gudfile, 'TRAC49').squeeze().transpose()
array2d_idepth_iT_largeeuk06[-1,:]=np.nan
array2d_idepth_iT_largeeuk07\
=netcdf_tools.read_netcdf(gudfile, 'TRAC50').squeeze().transpose()
array2d_idepth_iT_largeeuk07[-1,:]=np.nan
array2d_idepth_iT_largeeuk08\
=netcdf_tools.read_netcdf(gudfile, 'TRAC51').squeeze().transpose()
array2d_idepth_iT_largeeuk08[-1,:]=np.nan
array2d_idepth_iT_largeeuk09\
=netcdf_tools.read_netcdf(gudfile, 'TRAC52').squeeze().transpose()
array2d_idepth_iT_largeeuk09[-1,:]=np.nan
array2d_idepth_iT_largeeuk10\
=netcdf_tools.read_netcdf(gudfile, 'TRAC53').squeeze().transpose()
array2d_idepth_iT_largeeuk10[-1,:]=np.nan

array2d_idepth_iT_largeeuk\
=array2d_idepth_iT_largeeuk01+array2d_idepth_iT_largeeuk02\
+array2d_idepth_iT_largeeuk03+array2d_idepth_iT_largeeuk04\
+array2d_idepth_iT_largeeuk05+array2d_idepth_iT_largeeuk06\
+array2d_idepth_iT_largeeuk07+array2d_idepth_iT_largeeuk08\
+array2d_idepth_iT_largeeuk09+array2d_idepth_iT_largeeuk10

array2d_idepth_iT_phyto\
=array2d_idepth_iT_pro+array2d_idepth_iT_syn\
+array2d_idepth_iT_smalleuk+array2d_idepth_iT_cocco\
+array2d_idepth_iT_diazo+array2d_idepth_iT_tri\
+array2d_idepth_iT_diatom+array2d_idepth_iT_largeeuk

array2d_idepth_iT_zoo01\
=netcdf_tools.read_netcdf(gudfile, 'TRAC54').squeeze().transpose()
array2d_idepth_iT_zoo01[-1,:]=np.nan
array2d_idepth_iT_zoo02\
=netcdf_tools.read_netcdf(gudfile, 'TRAC55').squeeze().transpose()
array2d_idepth_iT_zoo02[-1,:]=np.nan
array2d_idepth_iT_zoo03\
=netcdf_tools.read_netcdf(gudfile, 'TRAC56').squeeze().transpose()
array2d_idepth_iT_zoo03[-1,:]=np.nan
array2d_idepth_iT_zoo04\
=netcdf_tools.read_netcdf(gudfile, 'TRAC57').squeeze().transpose()
array2d_idepth_iT_zoo04[-1,:]=np.nan
array2d_idepth_iT_zoo05\
=netcdf_tools.read_netcdf(gudfile, 'TRAC58').squeeze().transpose()
array2d_idepth_iT_zoo05[-1,:]=np.nan
array2d_idepth_iT_zoo06\
=netcdf_tools.read_netcdf(gudfile, 'TRAC59').squeeze().transpose()
array2d_idepth_iT_zoo06[-1,:]=np.nan
array2d_idepth_iT_zoo07\
=netcdf_tools.read_netcdf(gudfile, 'TRAC60').squeeze().transpose()
array2d_idepth_iT_zoo07[-1,:]=np.nan
array2d_idepth_iT_zoo08\
=netcdf_tools.read_netcdf(gudfile, 'TRAC61').squeeze().transpose()
array2d_idepth_iT_zoo08[-1,:]=np.nan
array2d_idepth_iT_zoo09\
=netcdf_tools.read_netcdf(gudfile, 'TRAC62').squeeze().transpose()
array2d_idepth_iT_zoo09[-1,:]=np.nan
array2d_idepth_iT_zoo10\
=netcdf_tools.read_netcdf(gudfile, 'TRAC63').squeeze().transpose()
array2d_idepth_iT_zoo10[-1,:]=np.nan
array2d_idepth_iT_zoo11\
=netcdf_tools.read_netcdf(gudfile, 'TRAC64').squeeze().transpose()
array2d_idepth_iT_zoo11[-1,:]=np.nan
array2d_idepth_iT_zoo12\
=netcdf_tools.read_netcdf(gudfile, 'TRAC65').squeeze().transpose()
array2d_idepth_iT_zoo12[-1,:]=np.nan
array2d_idepth_iT_zoo13\
=netcdf_tools.read_netcdf(gudfile, 'TRAC66').squeeze().transpose()
array2d_idepth_iT_zoo13[-1,:]=np.nan
array2d_idepth_iT_zoo14\
=netcdf_tools.read_netcdf(gudfile, 'TRAC67').squeeze().transpose()
array2d_idepth_iT_zoo14[-1,:]=np.nan
array2d_idepth_iT_zoo15\
=netcdf_tools.read_netcdf(gudfile, 'TRAC68').squeeze().transpose()
array2d_idepth_iT_zoo15[-1,:]=np.nan
array2d_idepth_iT_zoo16\
=netcdf_tools.read_netcdf(gudfile, 'TRAC69').squeeze().transpose()
array2d_idepth_iT_zoo16[-1,:]=np.nan

array2d_idepth_iT_zoo\
=array2d_idepth_iT_zoo01+array2d_idepth_iT_zoo02\
+array2d_idepth_iT_zoo03+array2d_idepth_iT_zoo04\
+array2d_idepth_iT_zoo05+array2d_idepth_iT_zoo06\
+array2d_idepth_iT_zoo07+array2d_idepth_iT_zoo08\
+array2d_idepth_iT_zoo09+array2d_idepth_iT_zoo10\
+array2d_idepth_iT_zoo11+array2d_idepth_iT_zoo12\
+array2d_idepth_iT_zoo13+array2d_idepth_iT_zoo14\
+array2d_idepth_iT_zoo15+array2d_idepth_iT_zoo16

array2d_idepth_iT_biomass=array2d_idepth_iT_phyto+array2d_idepth_iT_zoo

array2d_idepth_iT_C\
=array2d_idepth_iT_DIC+array2d_idepth_iT_PIC\
+array2d_idepth_iT_DOC+array2d_idepth_iT_DOC\
+array2d_idepth_iT_biomass

# %% [markdown]
# # Prepare plots of $DIC$, $PIC$, $DOC$, $POC$, $phyto$, $zoo$, $phyto$+$zoo$ and total C

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
# adapted from
# https://stackoverflow.com/questions/3899980/how-to-change-the-font-size-on-a-matplotlib-plot
# answer of Pedro M Duarte
SMALL_SIZE = 8
MEDIUM_SIZE = 20
BIGGER_SIZE = 28

# plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the x tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the y tick labels
# plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %% [markdown]
# # Vertical integration of carbon

# %%
import vstats

# %%
array1d_iT_C0to354  =vstats.vintegrate(array2d_idepth_iT_C, drF,  0, 73)
array1d_iT_C354to360=vstats.vintegrate(array2d_idepth_iT_C, drF, 73, 74)
array1d_iT_C0to360  =vstats.vintegrate(array2d_idepth_iT_C, drF,  0, 74)

# %% [markdown]
# # Annual drift of $C$

# %%
nbdepth=RF.size-1
array2d_idepth_iyr2tolast_deltaC=np.zeros((nbdepth,nbyr-1))
for iyr in range(2,nbyr+1):
    iTcurrent=365*(iyr-1)+364
    array1d_idepth_Ccurrent=array2d_idepth_iT_C[:,iTcurrent]
    iTprevious=365*(iyr-2)+364
    array1d_idepth_Cprevious=array2d_idepth_iT_C[:,iTprevious]
    array1d_idepth_deltaC=array1d_idepth_Ccurrent-array1d_idepth_Cprevious
    array2d_idepth_iyr2tolast_deltaC[:,iyr-2]=array1d_idepth_deltaC
array1d_iyr_yr=np.arange(1,nbyr+1)

# %% [markdown]
# # All plots on the same figure

# %%
plt.figure(figsize=(10,15))

plt.subplot2grid(shape=(3,2), loc=(0,0))
plt.pcolormesh(array1d_iT_iTforpcolormesh,RF,
               array2d_idepth_iT_DIC,
               cmap='jet',
               vmin=1980,
               vmax=2500
              )
plt.title('$a)\ DIC$')
plt.xlabel('$Year$')
plt.xticks(locs,xticklabels)
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
cbar=plt.colorbar()
cbar.set_label('$DIC\ (mmol\ C\ m^{-3})$')

plt.subplot2grid(shape=(3,2), loc=(0,1))
plt.pcolormesh(array1d_iT_iTforpcolormesh,RF,
               array2d_idepth_iT_PIC,
               cmap='jet',
               vmin=0,
               vmax=170
              )
plt.title('$b)\ PIC$')
plt.xlabel('$Year$')
plt.xticks(locs,xticklabels)
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
cbar=plt.colorbar()
cbar.set_label('$PIC\ (mmol\ C\ m^{-3})$')

plt.subplot2grid(shape=(3,2), loc=(1,0))
plt.pcolormesh(array1d_iT_iTforpcolormesh,RF,
               array2d_idepth_iT_DOC,
               cmap='jet'#,
#                vmin=0,
#                vmax=40
              )
plt.title('$c)\ DOC$')
plt.xlabel('$Year$')
plt.xticks(locs,xticklabels)
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
cbar=plt.colorbar()
cbar.set_label('$DOC\ (mmol\ C\ m^{-3})$')

plt.subplot2grid(shape=(3,2), loc=(1,1))
plt.pcolormesh(array1d_iT_iTforpcolormesh,RF,
               array2d_idepth_iT_POC,
               cmap='jet',
               vmin=0,
               vmax=170
              )
plt.title('$d)\ POC$')
plt.xlabel('$Year$')
plt.xticks(locs,xticklabels)
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
cbar=plt.colorbar()
cbar.set_label('$POC\ (mmol\ C\ m^{-3})$')

plt.subplot2grid(shape=(3,2), loc=(2,0))
plt.pcolormesh(array1d_iT_iTforpcolormesh,RF,
               array2d_idepth_iT_phyto,
               cmap='jet',
               vmin=0,
               vmax=40
              )
plt.title('$e)\ phyto$')
plt.xlabel('$Year$')
plt.xticks(locs,xticklabels)
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
cbar=plt.colorbar()
cbar.set_label('$phyto\ (mmol\ C\ m^{-3})$')

plt.subplot2grid(shape=(3,2), loc=(2,1))
plt.pcolormesh(array1d_iT_iTforpcolormesh,RF,
               array2d_idepth_iT_zoo,
               cmap='jet'#,
#                vmin=0,
#                vmax=40
              )
plt.title('$f)\ zoo$')
plt.xlabel('$Year$')
plt.xticks(locs,xticklabels)
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
cbar=plt.colorbar()
cbar.set_label('$zoo\ (mmol\ C\ m^{-3})$')

plt.tight_layout()

plt.savefig('car.0000000000.t001.allyears.c.largecbar1.png')

# %%
plt.figure(figsize=(10,15))

plt.subplot2grid(shape=(3,2), loc=(0,0))
plt.pcolormesh(array1d_iT_iTforpcolormesh,RF,
               array2d_idepth_iT_biomass,
               cmap='jet',
               vmin=0,
               vmax=40
              )
plt.title('$g)\ phyto+zoo$')
plt.xlabel('$Year$')
plt.xticks(locs,xticklabels)
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
cbar=plt.colorbar()
cbar.set_label('$biomass\ (mmol\ C\ m^{-3})$')

plt.subplot2grid(shape=(3,2), loc=(0,1))
plt.pcolormesh(array1d_iT_iTforpcolormesh,RF,
               array2d_idepth_iT_C,
               cmap='jet',
               vmin=1980,
               vmax=2500
              )
plt.title('$h)\ total\ C$')
plt.xlabel('$Year$')
plt.xticks(locs,xticklabels)
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
cbar=plt.colorbar()
cbar.set_label('$C\ (mmol\ C\ m^{-3})$')

plt.subplot2grid(shape=(3,2), loc=(1,0))
plt.plot(array1d_iT_iTforplot,array1d_iT_C0to354,  color='blue', linestyle='-',
         label='0 m to -354 m')
plt.plot(array1d_iT_iTforplot,array1d_iT_C0to360,  color='black',linestyle='-',
         label='0 m to -360 m')
plt.legend(loc='lower right')
plt.title('$i)\ total\ C\ above\ bottom$\n$\ and\ total\ C$')
plt.xlabel('Year')
plt.ylabel('$C\ (mmol\ C\ m^{-2})$')
plt.grid(True)
plt.xticks(locs,xticklabels)
plt.legend()

plt.subplot2grid(shape=(3,2), loc=(2,0))
plt.plot(array1d_iT_iTforplot,array1d_iT_C354to360,color='red',  linestyle='-',
         label='-354 m to -360 m')
plt.legend(loc='lower right')
plt.title('$j)\ total\ C$\n$\ at\ the\ bottom$')
plt.xlabel('Year')
plt.ylabel('$C\ (mmol\ C\ m^{-2})$')
plt.grid(True)
plt.xticks(locs,xticklabels)
plt.legend()

plt.subplot2grid(shape=(3,2), loc=(2,1))
plt.pcolormesh(array1d_iyr_yr, RF,
               array2d_idepth_iyr2tolast_deltaC,
               cmap='jet')
plt.title('$k)\ Annual\ drift\ of\ C$')
plt.xlabel('$Year$')
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
cbar=plt.colorbar()
cbar.set_label('$\Delta C\ (mmol\ C\ m^{-3})$')

plt.tight_layout()

plt.savefig('car.0000000000.t001.allyears.c.largecbar2.png')

# %%
import matplotlib.colors as colors
import matplotlib.cbook as cbook

plt.figure(figsize=(10,15))

plt.subplot2grid(shape=(3,2), loc=(0,0))
plt.pcolormesh(array1d_iT_iTforpcolormesh,RF,
               array2d_idepth_iT_DIC,
               cmap='jet',
               vmin=2000,
               vmax=2100
              )
plt.title('$a)\ DIC$')
plt.xlabel('$Year$')
plt.xticks(locs,xticklabels)
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
cbar=plt.colorbar()
cbar.set_label('$DIC\ (mmol\ C\ m^{-3})$')

plt.subplot2grid(shape=(3,2), loc=(0,1))
plt.pcolormesh(array1d_iT_iTforpcolormesh,RF,
               array2d_idepth_iT_PIC,
               cmap='jet',
               vmin=0,
               vmax=170
              )
plt.title('$b)\ PIC$')
plt.xlabel('$Year$')
plt.xticks(locs,xticklabels)
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
cbar=plt.colorbar()
cbar.set_label('$PIC\ (mmol\ C\ m^{-3})$')

plt.subplot2grid(shape=(3,2), loc=(1,0))
plt.pcolormesh(array1d_iT_iTforpcolormesh,RF,
               array2d_idepth_iT_DOC,
               cmap='jet'#,
#                vmin=0,
#                vmax=40
              )
plt.title('$c)\ DOC$')
plt.xlabel('$Year$')
plt.xticks(locs,xticklabels)
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
cbar=plt.colorbar()
cbar.set_label('$DOC\ (mmol\ C\ m^{-3})$')

plt.subplot2grid(shape=(3,2), loc=(1,1))
plt.pcolormesh(array1d_iT_iTforpcolormesh,RF,
               array2d_idepth_iT_POC,
               cmap='jet',
               vmin=0,
               vmax=170
              )
plt.title('$d)\ POC$')
plt.xlabel('$Year$')
plt.xticks(locs,xticklabels)
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
cbar=plt.colorbar()
cbar.set_label('$POC\ (mmol\ C\ m^{-3})$')

array2d_idepth_iT_phyto[np.isnan(array2d_idepth_iT_phyto)]=0
plt.subplot2grid(shape=(3,2), loc=(2,0))
plt.pcolormesh(array1d_iT_iTforpcolormesh,RF,
               array2d_idepth_iT_phyto,
               norm=colors.LogNorm(vmin=0.01, vmax=100),
               cmap='jet'
              )
plt.title('$e)\ phyto$')
plt.xlabel('$Year$')
plt.xticks(locs,xticklabels)
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
ticks=[0.01,0.1,1,10,100]
yticklabels=[str(i) for i in ticks]
cbar=plt.colorbar(ticks=ticks)
cbar.ax.set_yticklabels(yticklabels)
cbar.set_label('$phyto\ (mmol\ C\ m^{-3})$')

array2d_idepth_iT_zoo[np.isnan(array2d_idepth_iT_zoo)]=0
plt.subplot2grid(shape=(3,2), loc=(2,1))
plt.pcolormesh(array1d_iT_iTforpcolormesh,RF,
               array2d_idepth_iT_zoo,
               norm=colors.LogNorm(vmin=0.01, vmax=100),
               cmap='jet'
              )
plt.title('$f)\ zoo$')
plt.xlabel('$Year$')
plt.xticks(locs,xticklabels)
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
ticks=[0.01,0.1,1,10,100]
yticklabels=[str(i) for i in ticks]
cbar=plt.colorbar(ticks=ticks)
cbar.ax.set_yticklabels(yticklabels)
cbar.set_label('$zoo\ (mmol\ C\ m^{-3})$')

plt.tight_layout()

plt.savefig('car.0000000000.t001.allyears.c.smallcbar1.png')

# %%
plt.figure(figsize=(10,15))

array2d_idepth_iT_biomass[np.isnan(array2d_idepth_iT_biomass)]=0
plt.subplot2grid(shape=(3,2), loc=(0,0))
plt.pcolormesh(array1d_iT_iTforpcolormesh,RF,
               array2d_idepth_iT_biomass,
               cmap='jet',
               norm=colors.LogNorm(vmin=0.01, vmax=100)
              )
plt.title('$g)\ phyto+zoo$')
plt.xlabel('$Year$')
plt.xticks(locs,xticklabels)
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
ticks=[0.01,0.1,1,10,100]
yticklabels=[str(i) for i in ticks]
cbar=plt.colorbar(ticks=ticks)
cbar.ax.set_yticklabels(yticklabels)
cbar.set_label('$biomass\ (mmol\ C\ m^{-3})$')

plt.subplot2grid(shape=(3,2), loc=(0,1))
plt.pcolormesh(array1d_iT_iTforpcolormesh,RF,
               array2d_idepth_iT_C,
               cmap='jet',
               vmin=2000,
               vmax=2200
              )
plt.title('$h)\ total\ C$')
plt.xlabel('$Year$')
plt.xticks(locs,xticklabels)
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
cbar=plt.colorbar()
cbar.set_label('$C\ (mmol\ C\ m^{-3})$')

plt.subplot2grid(shape=(3,2), loc=(1,0))
plt.plot(array1d_iT_iTforplot,array1d_iT_C0to354,  color='blue', linestyle='-',
         label='0 m to -354 m')
plt.plot(array1d_iT_iTforplot,array1d_iT_C0to360,  color='black',linestyle='-',
         label='0 m to -360 m')
plt.legend(loc='lower right')
plt.title('$i)\ total\ C\ above\ bottom$\n$\ and\ total\ C$')
plt.xlabel('Year')
plt.ylabel('$C\ (mmol\ C\ m^{-2})$')
plt.grid(True)
plt.xticks(locs,xticklabels)
plt.legend()

plt.subplot2grid(shape=(3,2), loc=(2,0))
plt.plot(array1d_iT_iTforplot,array1d_iT_C354to360,color='red',  linestyle='-',
         label='-354 m to -360 m')
plt.legend(loc='lower right')
plt.title('$j)\ total\ C$\n$\ at\ the\ bottom$')
plt.xlabel('Year')
plt.ylabel('$C\ (mmol\ C\ m^{-2})$')
plt.grid(True)
plt.xticks(locs,xticklabels)
plt.legend()

plt.subplot2grid(shape=(3,2), loc=(2,1))
plt.pcolormesh(array1d_iyr_yr, RF,
               array2d_idepth_iyr2tolast_deltaC,
               cmap='jet',
               vmin=-10,
               vmax=40)
plt.title('$k)\ Annual\ drift\ of\ C$')
plt.xlabel('$Year$')
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
cbar=plt.colorbar()
cbar.set_label('$\Delta C\ (mmol\ C\ m^{-3})$')

plt.tight_layout()

plt.savefig('car.0000000000.t001.allyears.c.smallcbar2.png')

# %% [markdown]
# # Conclusion

# %% [markdown]
# **Is carbon at the equilibrium?**

# %% [markdown]
# No.

# %% [markdown]
# **Is there a drift of C?**

# %% [markdown]
# Yes.

# %% [markdown]
# # Generation of individual plots

# %% [markdown]
# ## Drift of total C

# %%
plt.figure(figsize=(6.4,4.8))
plt.pcolormesh(array1d_iT_iTforpcolormesh,RF,
               array2d_idepth_iT_C,
               cmap='jet',
               vmin=2000,
               vmax=2200
              )
plt.title('$total\ C$')
plt.xlabel('$Year$')
plt.xticks(locs,xticklabels)
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
cbar=plt.colorbar()
cbar.set_label('$C\ (mmol\ C\ m^{-3})$')
plt.tight_layout()
plt.savefig('car.0000000000.t001.allyears.c.totalC.png')

# %% [markdown]
# ## Equilibrium of carbon

# %%
plt.figure(figsize=(6.4,4.8))
plt.plot(array1d_iT_iTforplot,array1d_iT_C0to354,  color='blue', linestyle='-',
         label='0 m to -354 m')
plt.plot(array1d_iT_iTforplot,array1d_iT_C0to360,  color='black',linestyle='-',
         label='0 m to -360 m')
plt.legend(loc='lower right')
plt.title('$total\ C\ above\ bottom$\n$\ and\ total\ C$')
plt.xlabel('Year')
plt.ylim(745000,765000)
plt.ylabel('$C\ (mmol\ C\ m^{-2})$')
plt.grid(True)
plt.xticks(locs,xticklabels)
plt.legend()
plt.tight_layout()
plt.savefig('car.0000000000.t001.allyears.c.vintC.png')

# %% [markdown]
# ## Annual drift of $C$

# %%
plt.figure(figsize=(6.4,4.8))
plt.pcolormesh(array1d_iyr_yr, RF,
               array2d_idepth_iyr2tolast_deltaC,
               cmap='jet',
               vmin=-10,
               vmax=40)
plt.title('$Annual\ drift\ of\ C$')
plt.xlabel('$Year$')
plt.ylabel('$Depth\ (m)$')
plt.grid(True)
cbar=plt.colorbar()
cbar.set_label('$\Delta C\ (mmol\ C\ m^{-3})$')
plt.tight_layout()
plt.savefig('car.0000000000.t001.allyears.c.deltaC.png')
