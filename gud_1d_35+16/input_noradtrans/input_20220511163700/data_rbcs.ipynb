# %% [markdown]
# # Generate 1D_BB_NO3_GE_spring.delZ1016mm.32bits.times.*.bin

# %%
indir='../../../output/run_20211110_0000_EXP0_defineGUD_READ_PARUICE_grp_Xmin1Em2_10y/'

# %%
import matplotlib
import matplotlib.pyplot as plt
import netcdf_tools
import numpy as np
import os
import os.path

# %%
infile_no3='1D_BB_NO3_GE_spring.delZ1016mm.32bits.bin'
in_no3=np.fromfile(infile_no3,dtype='>f')
prefix='1D_BB_NO3_GE_spring.delZ1016mm.32bits.times.'
ext='.bin'

# %%
for f in [0.2,0.4,0.6,0.8,1.5,2.0,2.5,3.0]:
    out_no3=in_no3*f
    outfile=prefix+'{0:.2f}'.format(f)+ext
    out_no3.astype('>f4').tofile(outfile)

# %% [markdown]
# ## Verification

# %%
gridfile=os.path.join(indir, 'grid.t001.nc')
RC=netcdf_tools.read_netcdf(gridfile,'RC')

# %%
with plt.style.context('depth_profile.mplstyle'):
    plt.figure(figsize=(15,5))
    
    # --- STANDARD
    in_no3_standard=np.fromfile('1D_BB_NO3_GE_spring.delZ1016mm.32bits.bin',
                                dtype='>f')
    plt.plot(in_no3_standard,RC,color='black',ls='-',label='standard')
    plt.xlabel('$NO_3\ (mmol\ N\ m^{-3})$')
    plt.ylabel('$Depth\ (m)$')
    plt.xlim(0,90)
    plt.ylim(-400,0)
    plt.grid(True)
    plt.tight_layout()
    
    # --- dummy items to fill the legend
    plt.plot(0,0,color='white',label=' ')
    plt.plot(0,0,color='white',label=' ')
    plt.plot(0,0,color='white',label=' ')
    plt.plot(0,0,color='white',label=' ')
    plt.plot(0,0,color='white',label=' ')
    plt.plot(0,0,color='white',label=' ')
    plt.plot(0,0,color='white',label=' ')
    
    # --- -80%
    in_no3_times0_20=np.fromfile('1D_BB_NO3_GE_spring.delZ1016mm.32bits.times.0.20.bin',
                                 dtype='>f')
    plt.plot(in_no3_times0_20,RC,color='red',ls=':',label='-80%')
    
    # --- -60%
    in_no3_times0_40=np.fromfile('1D_BB_NO3_GE_spring.delZ1016mm.32bits.times.0.40.bin',
                                 dtype='>f')
    plt.plot(in_no3_times0_40,RC,color='magenta',ls=':',label='-60%')
    
    # --- -40%
    in_no3_times0_60=np.fromfile('1D_BB_NO3_GE_spring.delZ1016mm.32bits.times.0.60.bin',
                                 dtype='>f')
    plt.plot(in_no3_times0_60,RC,color='blue',ls=':',label='-40%')
    
    # --- -20%
    in_no3_times0_80=np.fromfile('1D_BB_NO3_GE_spring.delZ1016mm.32bits.times.0.80.bin',
                                 dtype='>f')
    plt.plot(in_no3_times0_80,RC,color='cyan',ls=':',label='-20%')
    
    # --- +50%
    in_no3_times1_50=np.fromfile('1D_BB_NO3_GE_spring.delZ1016mm.32bits.times.1.50.bin',
                                 dtype='>f')
    plt.plot(in_no3_times1_50,RC,color='red',ls='--',label='+50%')
    
    # --- +100%
    in_no3_times2_00=np.fromfile('1D_BB_NO3_GE_spring.delZ1016mm.32bits.times.2.00.bin',
                                 dtype='>f')
    plt.plot(in_no3_times2_00,RC,color='magenta',ls='--',label='+100%')
    
    # --- +150%
    in_no3_times2_50=np.fromfile('1D_BB_NO3_GE_spring.delZ1016mm.32bits.times.2.50.bin',
                                 dtype='>f')
    plt.plot(in_no3_times2_50,RC,color='blue',ls='--',label='+150%')
    
    # --- +200%
    in_no3_times3_00=np.fromfile('1D_BB_NO3_GE_spring.delZ1016mm.32bits.times.3.00.bin',
                                 dtype='>f')
    plt.plot(in_no3_times3_00,RC,color='cyan',ls='--',label='+200%')
    plt.legend(ncol=2)

    # --- SAVE
    plt.savefig('exp2_1.png')
